# %%
import pyfolio as pf
# Out:
# C:\ProgramData\Anaconda3\envs\zipline\lib\site-packages\pyfolio\pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'

# %%
import eikon as ek

ek.set_app_key('8ee143628de84818a8b12f4f55be35674e136d08')
df_eikon = ek.get_timeseries(["10TBc1"],
                             fields="*",
                             start_date="2015-01-01",
                             end_date = "2020-01-11",
                             interval = "daily"
                            )
df_eikon.tail(5)
# Out:
# 10TBc1        HIGH     LOW    OPEN   CLOSE    VOLUME
# Date
# 2020-01-06  131.93  131.37  131.64  131.37   97956.0
# 2020-01-07  131.20  130.55  131.20  130.55  103213.0
# 2020-01-08  131.31  130.41  131.05  130.41  150755.0
# 2020-01-09  130.40  129.60  130.31  129.68   82427.0
# 2020-01-10  129.95  129.19  129.86  129.25   93065.0

# %%
rs = df_eikon['CLOSE'].pct_change().fillna(0)

# %%
pf.create_full_tear_sheet(rs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-01-10</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>58</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>1.5%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>7.4%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.4%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-11.4%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.19</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>2.34</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.5%</td>
#     </tr>
#   </tbody>
# </table>
# C:\ProgramData\Anaconda3\envs\zipline\lib\site-packages\numpy\core\fromnumeric.py:61: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   return bound(*args, **kwds)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11.42</td>
#       <td>2016-07-28</td>
#       <td>2018-02-05</td>
#       <td>2019-08-05</td>
#       <td>788</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.44</td>
#       <td>2019-08-16</td>
#       <td>2019-11-12</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.29</td>
#       <td>2015-04-06</td>
#       <td>2015-05-12</td>
#       <td>2015-09-30</td>
#       <td>128</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.36</td>
#       <td>2015-10-28</td>
#       <td>2015-11-13</td>
#       <td>2016-01-07</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.18</td>
#       <td>2015-02-03</td>
#       <td>2015-02-16</td>
#       <td>2015-03-24</td>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fall2015</th>
#       <td>0.06%</td>
#       <td>-0.30%</td>
#       <td>0.62%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-1.52%</td>
#       <td>1.28%</td>
#     </tr>
#   </tbody>
# </table>
